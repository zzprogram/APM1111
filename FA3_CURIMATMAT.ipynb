# %%
import pandas as pd
import numpy as np
from scipy import stats

#Data

scores = [
    88, 45, 53, 86, 33, 86, 85, 30, 89, 53, 41, 96, 56, 38, 62,
    71, 51, 86, 68, 29, 28, 47, 33, 37, 25, 36, 33, 94, 73, 46,
    42, 34, 79, 72, 88, 99, 82, 62, 57, 42, 28, 55, 67, 62, 60,
    96, 61, 57, 75, 93, 34, 75, 53, 32, 28, 73, 51, 69, 91, 35
]

# Calculate
df = pd.Series(scores)

results = {
    "Valid": df.count(),
    "Mode": df.mode()[0], # Returns the first mode found
    "Median": df.median(),
    "Mean": df.mean(),
    "Std. Deviation": df.std(),
    "Variance": df.var(),
    "Skewness": df.skew(),
    "Kurtosis": df.kurtosis(),
    "Minimum": df.min(),
    "Maximum": df.max(),
    "25th percentile (Q1)": df.quantile(0.25),
    "50th percentile (Q2)": df.quantile(0.50),
    "75th percentile (Q3)": df.quantile(0.75),
    "90th percentile (D9)": df.quantile(0.90),
    "95th percentile (P95)": df.quantile(0.95)
}

#Format of the Table 
print("Descriptive Table: \n")
style_table = pd.DataFrame.from_dict(results, orient='index', columns=['Score'])
table_styles = [
    {'selector': 'th:first-child', 'props': [('text-align', 'left')]},
    {'selector': 'td', 'props': [('text-align', 'center')]}
]

display(style_table.round(3).style.format({"Score": "  {:.3f}"}).set_table_styles(table_styles))
# Out:
# Descriptive Table:
# <style type="text/css">
# #T_e3eb9 th:first-child {
#   text-align: left;
# }
# #T_e3eb9 td {
#   text-align: center;
# }
# </style>
# <table id="T_e3eb9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3eb9_level0_col0" class="col_heading level0 col0" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3eb9_level0_row0" class="row_heading level0 row0" >Valid</th>
#       <td id="T_e3eb9_row0_col0" class="data row0 col0" >  60.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row1" class="row_heading level0 row1" >Mode</th>
#       <td id="T_e3eb9_row1_col0" class="data row1 col0" >  28.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row2" class="row_heading level0 row2" >Median</th>
#       <td id="T_e3eb9_row2_col0" class="data row2 col0" >  57.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row3" class="row_heading level0 row3" >Mean</th>
#       <td id="T_e3eb9_row3_col0" class="data row3 col0" >  59.167</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row4" class="row_heading level0 row4" >Std. Deviation</th>
#       <td id="T_e3eb9_row4_col0" class="data row4 col0" >  22.211</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row5" class="row_heading level0 row5" >Variance</th>
#       <td id="T_e3eb9_row5_col0" class="data row5 col0" >  493.328</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row6" class="row_heading level0 row6" >Skewness</th>
#       <td id="T_e3eb9_row6_col0" class="data row6 col0" >  0.167</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row7" class="row_heading level0 row7" >Kurtosis</th>
#       <td id="T_e3eb9_row7_col0" class="data row7 col0" >  -1.244</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row8" class="row_heading level0 row8" >Minimum</th>
#       <td id="T_e3eb9_row8_col0" class="data row8 col0" >  25.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row9" class="row_heading level0 row9" >Maximum</th>
#       <td id="T_e3eb9_row9_col0" class="data row9 col0" >  99.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row10" class="row_heading level0 row10" >25th percentile (Q1)</th>
#       <td id="T_e3eb9_row10_col0" class="data row10 col0" >  37.750</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row11" class="row_heading level0 row11" >50th percentile (Q2)</th>
#       <td id="T_e3eb9_row11_col0" class="data row11 col0" >  57.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row12" class="row_heading level0 row12" >75th percentile (Q3)</th>
#       <td id="T_e3eb9_row12_col0" class="data row12 col0" >  76.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row13" class="row_heading level0 row13" >90th percentile (D9)</th>
#       <td id="T_e3eb9_row13_col0" class="data row13 col0" >  89.200</td>
#     </tr>
#     <tr>
#       <th id="T_e3eb9_level0_row14" class="row_heading level0 row14" >95th percentile (P95)</th>
#       <td id="T_e3eb9_row14_col0" class="data row14 col0" >  94.100</td>
#     </tr>
#   </tbody>
# </table>
